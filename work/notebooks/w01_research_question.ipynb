# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Devaaldo/flyrank-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I chose Lane 2: Refresh / Content Opportunity Scoring, because I already
# explored this exact problem in Weeks 1-2 (notebooks 01 and 02) — comparing
# a hand-written rule against a learned model to rank pages for review.
# This lane lets me build directly on that foundation instead of starting
# a new problem from scratch, and the starter dataset already gives me
# everything I need to start testing ideas immediately.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The decision this work improves: which of a client's pages should the SEO
# team review first, given limited time.
#
# The unit of analysis: one page (content_id), scored using its trailing
# 90-day metrics.
#
# The action: a reviewer opens the top-ranked pages and decides whether to
# refresh the content, adjust metadata, or leave it monitored.
#
# The cost of a wrong call: if the model ranks a healthy page as high-priority,
# the team wastes review time on a page that didn't need attention — while a
# genuinely declining page waits longer than it should. The cost is time and
# opportunity, not immediate financial loss.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# Three real numbers from the starter dataset that show why this lane is worth pursuing:

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, subprocess, sys
import pandas as pd

REPO_DIR = "flyrank-ml-internship-starter"
if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1",
                     "https://github.com/Devaaldo/flyrank-ml", REPO_DIR], check=True)
os.chdir(REPO_DIR)

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

declining_pct = (df["trend_direction"] == "down").mean()
print(f"1. {declining_pct:.1%} of pages are currently in the 'declining' bucket.")

stale_visible = ((df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)).sum()
print(f"2. {stale_visible:,} pages are both stale (180+ days) and still visible (500+ impressions).")

print("3. Week 1-2 testing showed Precision@50 = 0.240 (hand rule) vs up to 0.740 (model) - a ~3x lift.")
# Out:
# 1. 54.2% of pages are currently in the 'declining' bucket.
# 2. 17 pages are both stale (180+ days) and still visible (500+ impressions).
# 3. Week 1-2 testing showed Precision@50 = 0.240 (hand rule) vs up to 0.740 (model) - a ~3x lift.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This work CAN say: which pages show observable signs of decline or
# opportunity, based on measurable patterns in the trailing data, and that
# a ranked review queue can help a team prioritize limited review time.
#
# This work CANNOT say: that refreshing a page will cause it to recover
# (that requires a real experiment), or that any pattern found here reflects
# how Google's ranking algorithm actually works. All claims are observational
# and directional, not causal.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
